# %%
import lib.db_connector as db_connector
import pandas as pd

#Set to true if database connection is not available
local = True

if not local:
    db = db_connector.DbConnector(db_name = 'speakql_study', verbose = False)
# Out:
# Initializing DbConnector class for a mysql  connection to speakql_study
# Attempting to connect to speakql_study
# DBCONNECTOR: Connected to 8.0.32-0buntu0.22.04.1

# %% [markdown]
# #### Get existing data from speakql_study db

# %%
if not local:
    feature_df = db.do_single_select_query_into_dataframe('select * from feature_usage')
    feature_df.to_excel('./data/df/feature-usage-determination-feature-df.xlsx')
else:
    feature_df = pd.read_excel('./data/df/feature-usage-determination-feature-df.xlsx')
feature_df
# Out:
#      Unnamed: 0                                           filename  \
# 0             0  username-participant1_queryid-7_session-39_ste...
# 1             1  username-participant1_queryid-14_session-39_st...
# 2             2  username-participant2_queryid-4_session-41_ste...
# 3             3  username-participant3_queryid-16_session-44_st...
# 4             4  username-participant3_queryid-4_session-44_ste...
# ..          ...                                                ...
# 915         915  username-participant23_queryid-5_session-66_st...
# 916         916  username-participant23_queryid-7_session-66_st...
# 917         917  username-participant23_queryid-7_session-66_st...
# 918         918  username-participant23_queryid-9_session-66_st...
# 919         919  username-participant23_queryid-9_session-66_st...
#
#      used_synonyms  used_unbundling  used_natural_functions  \
# 0            False             True                   False
# 1             True             True                    True
# 2            False            False                   False
# 3            False            False                   False
# 4            False            False                   False
# ..             ...              ...                     ...
# 915          False            False                    True
# 916           True             True                   False
# 917          False            False                   False
# 918          False             True                    True
# 919          False            False                   False
#
#      used_expression_ordering  has_min_kws  used_mod_ordering
# 0                       False         True              False
# 1                       False         True              False
# 2                       False         True              False
# 3                       False         True              False
# 4                        True         True              False
# ..                        ...          ...                ...
# 915                     False         True              False
# 916                     False         True              False
# 917                     False         True              False
# 918                      True         True              False
# 919                     False         True              False
#
# [920 rows x 8 columns]

# %% [markdown]
# #### Get transcript data from SpeakQL study DB:

# %%
transcripts = db.do_single_select_query_into_dataframe('select * from whisper_transcripts order by filename')
transcripts
# Out:
#                                               filename  \
# 0    username-participant1_queryid-1_session-39_ste...
# 1    username-participant1_queryid-1_session-39_ste...
# 2    username-participant1_queryid-10_session-39_st...
# 3    username-participant1_queryid-10_session-39_st...
# 4    username-participant1_queryid-11_session-39_st...
# ..                                                 ...
# 915  username-participant9_queryid-7_session-50_ste...
# 916  username-participant9_queryid-9_session-50_ste...
# 917  username-participant9_queryid-9_session-50_ste...
# 918  username-participant9_queryid-9_session-50_ste...
# 919  username-test2_queryid-9_session-43_step-11_qu...
#
#                                             transcript
# 0                   from term table get distinct year.
# 1                       Select Distinct ear from turn.
# 2     Select building name from building table and ...
# 3     Select building name from building table and ...
# 4     Select nothing from term table where year is ...
# ..                                                 ...
# 915   A as bracket select building ID from room whe...
# 916   Select count of building ID from the room tab...
# 917   A as bracket select building ID from room whe...
# 918   A as bracket select building ID from room whe...
# 919   In the room table, what is the count distinct...
#
# [920 rows x 2 columns]

# %% [markdown]
# #### Synonym usage determination:

# %%
synonyms = [
    "RETRIEVE", "SHOW ME", "DISPLAY", "PRESENT", "FIND", "GET", "WHAT IS", "WHAT ARE", "WHAT IS THE",
    "WHAT ARE THE", "FROM TABLE", "FROM TABLES", "IN TABLE", "IN TABLES", "JOIN TABLE", "BY JOINING",
    "BY JOINING TABLE", "JOINED WITH", "JOIN WITH", "JOINED WITH TABLE", "JOIN WITH TABLE", 
    "BY JOINING WITH TABLE", "BY JOINING WITH"
]

def has_synonym(transcript, synonyms):
    for synonym in synonyms:
        if synonym.lower() in transcript.lower():
            return True
    return False

transcripts['used_synonyms'] = transcripts.apply(
    lambda row: has_synonym(row.transcript, synonyms),
    axis = 1
)

transcripts
# Out:
#                                               filename  \
# 0    username-participant1_queryid-1_session-39_ste...
# 1    username-participant1_queryid-1_session-39_ste...
# 2    username-participant1_queryid-10_session-39_st...
# 3    username-participant1_queryid-10_session-39_st...
# 4    username-participant1_queryid-11_session-39_st...
# ..                                                 ...
# 915  username-participant9_queryid-7_session-50_ste...
# 916  username-participant9_queryid-9_session-50_ste...
# 917  username-participant9_queryid-9_session-50_ste...
# 918  username-participant9_queryid-9_session-50_ste...
# 919  username-test2_queryid-9_session-43_step-11_qu...
#
#                                             transcript  used_synonyms
# 0                   from term table get distinct year.           True
# 1                       Select Distinct ear from turn.          False
# 2     Select building name from building table and ...           True
# 3     Select building name from building table and ...           True
# 4     Select nothing from term table where year is ...          False
# ..                                                 ...            ...
# 915   A as bracket select building ID from room whe...          False
# 916   Select count of building ID from the room tab...          False
# 917   A as bracket select building ID from room whe...          False
# 918   A as bracket select building ID from room whe...          False
# 919   In the room table, what is the count distinct...           True
#
# [920 rows x 3 columns]

# %% [markdown]
# #### Unbundling Usage Determination:

# %%
transcripts['used_unbundling'] = transcripts.apply(
    lambda row: True if 'and then' in row.transcript.lower() else False,
    axis = 1
)

transcripts['p23'] = transcripts.apply(lambda row: row['filename'] if 'participant23' in row['filename'] else 0, axis = 1)
transcripts.where(transcripts.p23 != 0).dropna(how = 'all')
# Out:
#                                               filename  \
# 613  username-participant23_queryid--1_session-66_s...
# 614  username-participant23_queryid-1_session-66_st...
# 615  username-participant23_queryid-1_session-66_st...
# 616  username-participant23_queryid-10_session-66_s...
# 617  username-participant23_queryid-10_session-66_s...
# 618  username-participant23_queryid-11_session-66_s...
# 619  username-participant23_queryid-11_session-66_s...
# 620  username-participant23_queryid-11_session-66_s...
# 621  username-participant23_queryid-12_session-66_s...
# 622  username-participant23_queryid-12_session-66_s...
# 623  username-participant23_queryid-13_session-66_s...
# 624  username-participant23_queryid-13_session-66_s...
# 625  username-participant23_queryid-14_session-66_s...
# 626  username-participant23_queryid-14_session-66_s...
# 627  username-participant23_queryid-14_session-66_s...
# 628  username-participant23_queryid-15_session-66_s...
# 629  username-participant23_queryid-15_session-66_s...
# 630  username-participant23_queryid-16_session-66_s...
# 631  username-participant23_queryid-16_session-66_s...
# 632  username-participant23_queryid-16_session-66_s...
# 633  username-participant23_queryid-17_session-66_s...
# 634  username-participant23_queryid-17_session-66_s...
# 635  username-participant23_queryid-17_session-66_s...
# 636  username-participant23_queryid-2_session-66_st...
# 637  username-participant23_queryid-2_session-66_st...
# 638  username-participant23_queryid-3_session-66_st...
# 639  username-participant23_queryid-3_session-66_st...
# 640  username-participant23_queryid-4_session-66_st...
# 641  username-participant23_queryid-4_session-66_st...
# 642  username-participant23_queryid-5_session-66_st...
# 643  username-participant23_queryid-5_session-66_st...
# 644  username-participant23_queryid-5_session-66_st...
# 645  username-participant23_queryid-7_session-66_st...
# 646  username-participant23_queryid-7_session-66_st...
# 647  username-participant23_queryid-9_session-66_st...
# 648  username-participant23_queryid-9_session-66_st...
#
#                                             transcript  used_synonyms  \
# 613   I think I know. Yeah, go ahead and press stop...            0.0
# 614                     Get a distinct year from term.            1.0
# 615                      Select Distinct Ear from Turn            0.0
# 616   Select sum of wheelchair spaces from room R a...            0.0
# 617   Select building name, sum, wheel chair spaces...            0.0
# 618   Select title from course C and then select no...            0.0
# 619   Select title from course C, join course C on ...            0.0
# 620   Select title from course C, join course offer...            0.0
# 621   Select department name from department D and ...            0.0
# 622   Select Department Name, Count, Parenthesis, D...            0.0
# 623   Select department name from department D and ...            0.0
# 624   Select department name, count parenthesis dis...            0.0
# 625   Select building name, building number from bu...            0.0
# 626   Select building name, building number from bu...            0.0
# 627   Select building name, building number, averag...            0.0
# 628   Select building name, building number from bu...            0.0
# 629   Select building name, building number, averag...            0.0
# 630   Select nothing from course where ID equals an...            0.0
# 631   Select nothing from course where ID is equal ...            0.0
# 632   Select year, term period from term t, join co...            0.0
# 633   Select title from course C and then select no...            0.0
# 634   Select title from course C and then select no...            0.0
# 635   Select title from course C, join course offer...            0.0
# 636   Select count parenthesis distinct ID parenthe...            0.0
# 637            Select count distinct ID from building.            0.0
# 638   Select count parenthesis distinct ID parenthe...            0.0
# 639          Select Count Distinct ID from Department.            0.0
# 640   Select C.title, C.units from course C, join d...            0.0
# 641   Get title and units from course C and then se...            1.0
# 642   Get count of room id from room where wheelcha...            1.0
# 643   Get count of distinct ID from room where whee...            1.0
# 644   Select count ID from room where the chairs sp...            0.0
# 645   Get building name from building B and then se...            1.0
# 646   Select building name from building B, join ro...            0.0
# 647   Select count of ID from building B and then s...            0.0
# 648   Select count parenthesis distinct B.ID parent...            0.0
#
#      used_unbundling                                                p23
# 613              0.0  username-participant23_queryid--1_session-66_s...
# 614              0.0  username-participant23_queryid-1_session-66_st...
# 615              0.0  username-participant23_queryid-1_session-66_st...
# 616              1.0  username-participant23_queryid-10_session-66_s...
# 617              0.0  username-participant23_queryid-10_session-66_s...
# 618              1.0  username-participant23_queryid-11_session-66_s...
# 619              0.0  username-participant23_queryid-11_session-66_s...
# 620              0.0  username-participant23_queryid-11_session-66_s...
# 621              1.0  username-participant23_queryid-12_session-66_s...
# 622              0.0  username-participant23_queryid-12_session-66_s...
# 623              1.0  username-participant23_queryid-13_session-66_s...
# 624              0.0  username-participant23_queryid-13_session-66_s...
# 625              1.0  username-participant23_queryid-14_session-66_s...
# 626              1.0  username-participant23_queryid-14_session-66_s...
# 627              0.0  username-participant23_queryid-14_session-66_s...
# 628              1.0  username-participant23_queryid-15_session-66_s...
# 629              0.0  username-participant23_queryid-15_session-66_s...
# 630              1.0  username-participant23_queryid-16_session-66_s...
# 631              1.0  username-participant23_queryid-16_session-66_s...
# 632              0.0  username-participant23_queryid-16_session-66_s...
# 633              1.0  username-participant23_queryid-17_session-66_s...
# 634              1.0  username-participant23_queryid-17_session-66_s...
# 635              0.0  username-participant23_queryid-17_session-66_s...
# 636              0.0  username-participant23_queryid-2_session-66_st...
# 637              0.0  username-participant23_queryid-2_session-66_st...
# 638              0.0  username-participant23_queryid-3_session-66_st...
# 639              0.0  username-participant23_queryid-3_session-66_st...
# 640              0.0  username-participant23_queryid-4_session-66_st...
# 641              1.0  username-participant23_queryid-4_session-66_st...
# 642              0.0  username-participant23_queryid-5_session-66_st...
# 643              0.0  username-participant23_queryid-5_session-66_st...
# 644              0.0  username-participant23_queryid-5_session-66_st...
# 645              1.0  username-participant23_queryid-7_session-66_st...
# 646              0.0  username-participant23_queryid-7_session-66_st...
# 647              1.0  username-participant23_queryid-9_session-66_st...
# 648              0.0  username-participant23_queryid-9_session-66_st...

# %% [markdown]
# #### Natural Function Usage Determination

# %%
function_patterns = [
    "the count", "count of", "the sum", "sum of", "the average", "average of"
]

function_keywords = ["count", "sum", "average"]

def used_nat_func(transcript):
    # Check if used the or of keywords and return true if used
    for pattern in function_patterns:
        if pattern in transcript:
            return True
    # Check if functions used without parentheses and return true if used
    no_parens = False
    for kw in function_keywords:
        if kw in transcript:
            no_parens = True
            for p in ['parenthesis', 'parentheses']:
                if p in transcript:
                    no_parens = False
    
    return no_parens
    

transcripts['used_natural_functions'] = transcripts.apply(
    lambda row: used_nat_func(row.transcript),
    axis = 1
)

# %% [markdown]
# #### Alternate Ordering Usage Determination
# Run the following cell first before running either expression or modifier reordering determination

# %%
from lib.SpeakqlKeywords import SpeakQlKeywords 
spkw = SpeakQlKeywords()

# %%
def used_alternate_ordering(transcript, spkw):
    queries = transcript.upper().split('AND THEN')
    from_position = -1
    select_position = -1
    where_position = -1
    used_alt = False
    
    for query in queries:
        for kw in spkw.from_kw:
            frm_loc = query.find(kw)
            if frm_loc > from_position:
                from_position = frm_loc
    
        for kw in spkw.select_kw:
            sel_loc = query.find(kw)
            if sel_loc > select_position:
                select_position = sel_loc
                
        where_loc = query.find('WHERE')
        if where_loc > where_position:
            where_position = where_loc
            
    return (
           (from_position < select_position) 
        or (((from_position > where_position) or (select_position > where_position)) and where_position > -1)
    )

transcripts['used_expression_ordering'] = transcripts.apply(
    lambda row: used_alternate_ordering(row.transcript, spkw),
    axis = 1
)

transcripts
# Out:
#                                               filename  \
# 0    username-participant1_queryid-1_session-39_ste...
# 1    username-participant1_queryid-1_session-39_ste...
# 2    username-participant1_queryid-10_session-39_st...
# 3    username-participant1_queryid-10_session-39_st...
# 4    username-participant1_queryid-11_session-39_st...
# ..                                                 ...
# 915  username-participant9_queryid-7_session-50_ste...
# 916  username-participant9_queryid-9_session-50_ste...
# 917  username-participant9_queryid-9_session-50_ste...
# 918  username-participant9_queryid-9_session-50_ste...
# 919  username-test2_queryid-9_session-43_step-11_qu...
#
#                                             transcript  used_synonyms  \
# 0                   from term table get distinct year.           True
# 1                       Select Distinct ear from turn.          False
# 2     Select building name from building table and ...           True
# 3     Select building name from building table and ...           True
# 4     Select nothing from term table where year is ...          False
# ..                                                 ...            ...
# 915   A as bracket select building ID from room whe...          False
# 916   Select count of building ID from the room tab...          False
# 917   A as bracket select building ID from room whe...          False
# 918   A as bracket select building ID from room whe...          False
# 919   In the room table, what is the count distinct...           True
#
#      used_unbundling p23  used_natural_functions  used_expression_ordering
# 0              False   0                   False                     False
# 1              False   0                   False                     False
# 2               True   0                    True                     False
# 3               True   0                    True                     False
# 4               True   0                   False                     False
# ..               ...  ..                     ...                       ...
# 915            False   0                   False                     False
# 916            False   0                    True                     False
# 917            False   0                    True                     False
# 918            False   0                    True                     False
# 919            False   0                    True                      True
#
# [920 rows x 7 columns]

# %%
def used_modifier_ordering(transcript):
    NOT_IN_QUERY = 1000000
    
    queries = transcript.upper().split("AND THEN")
    
    for q in queries:
        gb_pos = q.find("GROUP BY")
        if gb_pos == -1:
            gb_pos = NOT_IN_QUERY
        h_pos = q.find("HAVING")
        if h_pos == -1:
            h_pos = NOT_IN_QUERY
        ob_pos = q.find("ORDER BY")
        if ob_pos == -1:
            ob_pos = NOT_IN_QUERY
        l_pos = q.find("LIMIT")
        if l_pos == -1:
            l_pos = NOT_IN_QUERY
        
    if gb_pos != NOT_IN_QUERY and (gb_pos > h_pos or gb_pos > ob_pos or gb_pos > l_pos):
        return True
    
    if h_pos != NOT_IN_QUERY and (h_pos > ob_pos or h_pos > l_pos):
        return True
    
    if ob_pos != NOT_IN_QUERY and (ob_pos > l_pos):
        return True
    
    return False
            
transcripts['used_mod_ordering'] = transcripts.apply(
    lambda row: used_modifier_ordering(row.transcript),
    axis = 1
)

transcripts
# Out:
#                                               filename  \
# 0    username-participant1_queryid-1_session-39_ste...
# 1    username-participant1_queryid-1_session-39_ste...
# 2    username-participant1_queryid-10_session-39_st...
# 3    username-participant1_queryid-10_session-39_st...
# 4    username-participant1_queryid-11_session-39_st...
# ..                                                 ...
# 915  username-participant9_queryid-7_session-50_ste...
# 916  username-participant9_queryid-9_session-50_ste...
# 917  username-participant9_queryid-9_session-50_ste...
# 918  username-participant9_queryid-9_session-50_ste...
# 919  username-test2_queryid-9_session-43_step-11_qu...
#
#                                             transcript  used_synonyms  \
# 0                   from term table get distinct year.           True
# 1                       Select Distinct ear from turn.          False
# 2     Select building name from building table and ...           True
# 3     Select building name from building table and ...           True
# 4     Select nothing from term table where year is ...          False
# ..                                                 ...            ...
# 915   A as bracket select building ID from room whe...          False
# 916   Select count of building ID from the room tab...          False
# 917   A as bracket select building ID from room whe...          False
# 918   A as bracket select building ID from room whe...          False
# 919   In the room table, what is the count distinct...           True
#
#      used_unbundling p23  used_natural_functions  used_expression_ordering  \
# 0              False   0                   False                     False
# 1              False   0                   False                     False
# 2               True   0                    True                     False
# 3               True   0                    True                     False
# 4               True   0                   False                     False
# ..               ...  ..                     ...                       ...
# 915            False   0                   False                     False
# 916            False   0                    True                     False
# 917            False   0                    True                     False
# 918            False   0                    True                     False
# 919            False   0                    True                      True
#
#      used_mod_ordering
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ..                 ...
# 915              False
# 916              False
# 917              False
# 918              False
# 919              False
#
# [920 rows x 8 columns]

# %%
def min_req_kws(transcript, spkw):
    has_from = False
    has_select = False
    query = transcript.upper()
    for kw in spkw.from_kw:
        if kw in query:
            has_from = True
    for kw in spkw.select_kw:
        if kw in query:
            has_select = True
            
    return has_select and has_from

transcripts['has_min_kws'] = transcripts.apply(
    lambda row: min_req_kws(row.transcript, spkw),
    axis = 1
)

transcripts
# Out:
#                                               filename  \
# 0    username-participant1_queryid-1_session-39_ste...
# 1    username-participant1_queryid-1_session-39_ste...
# 2    username-participant1_queryid-10_session-39_st...
# 3    username-participant1_queryid-10_session-39_st...
# 4    username-participant1_queryid-11_session-39_st...
# ..                                                 ...
# 915  username-participant9_queryid-7_session-50_ste...
# 916  username-participant9_queryid-9_session-50_ste...
# 917  username-participant9_queryid-9_session-50_ste...
# 918  username-participant9_queryid-9_session-50_ste...
# 919  username-test2_queryid-9_session-43_step-11_qu...
#
#                                             transcript  used_synonyms  \
# 0                   from term table get distinct year.           True
# 1                       Select Distinct ear from turn.          False
# 2     Select building name from building table and ...           True
# 3     Select building name from building table and ...           True
# 4     Select nothing from term table where year is ...          False
# ..                                                 ...            ...
# 915   A as bracket select building ID from room whe...          False
# 916   Select count of building ID from the room tab...          False
# 917   A as bracket select building ID from room whe...          False
# 918   A as bracket select building ID from room whe...          False
# 919   In the room table, what is the count distinct...           True
#
#      used_unbundling p23  used_natural_functions  used_expression_ordering  \
# 0              False   0                   False                     False
# 1              False   0                   False                     False
# 2               True   0                    True                     False
# 3               True   0                    True                     False
# 4               True   0                   False                     False
# ..               ...  ..                     ...                       ...
# 915            False   0                   False                     False
# 916            False   0                    True                     False
# 917            False   0                    True                     False
# 918            False   0                    True                     False
# 919            False   0                    True                      True
#
#      used_mod_ordering  has_min_kws
# 0                False         True
# 1                False         True
# 2                False         True
# 3                False         True
# 4                False         True
# ..                 ...          ...
# 915              False         True
# 916              False         True
# 917              False         True
# 918              False         True
# 919              False         True
#
# [920 rows x 9 columns]

# %% [markdown]
# ## Data Export Jobs

# %% [markdown]
# #### Export to Excel:

# %%
transcripts.to_excel("./features_used.xlsx")

# %% [markdown]
# #### Insert into study database (Only run if new data is processed)

# %%
query = """insert into feature_usage(
filename, used_synonyms, used_unbundling, used_natural_functions, used_expression_ordering, has_min_kws, used_mod_ordering
) values (
'{}', '{}', '{}', '{}', '{}', '{}', '{}'
)"""

existing_rows = db.do_single_select_query_into_dataframe("select * from feature_usage")
existing_rows

for row in transcripts.itertuples():
    if row.filename not in existing_rows.filename.to_list():
        insert_q = query.format(
                row.filename, 
                row.used_synonyms, 
                row.used_unbundling, 
                row.used_natural_functions, 
                row.used_expression_ordering, 
                row.has_min_kws, 
                row.used_mod_ordering)
        print(insert_q)
    
        db.do_single_insert_query_into_dataframe(
            insert_q
        )
